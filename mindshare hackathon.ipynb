# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("C:/Users/micha/Downloads/young_females.csv",index_col=0)

# %%
df2 = pd.read_csv("C:/Users/micha/Downloads/older_females.csv",index_col=0)

# %% [markdown]
# 4233 observations for young_female dataset
# 6956 observations for old_female dataset

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4233 entries, 25154 to 44014
# Columns: 1338 entries, RespID to TV (Day time) III (Light)
# dtypes: int64(1338)
# memory usage: 43.2 MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6956 entries, 25156 to 44010
# Columns: 1338 entries, RespID to TV (Day time) III (Light)
# dtypes: int64(1338)
# memory usage: 71.1 MB

# %%
df1.columns
# Out:
# Index(['RespID', 'wgtpop', 'Database Total Audience',
#        'Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader',
#        'Men', 'Women', 'Parents', 'Educ: graduated college plus',
#        'Educ: attended college', 'Educ: graduated high school',
#        ...
#        'Outdoor IV', 'Outdoor V (Light)', 'TV (Prime time) I (Heavy)',
#        'TV (Prime time) II', 'TV (Prime time) III', 'TV (Prime time) IV',
#        'TV (Prime time) V (Light)', 'TV (Day time) I (Heavy)',
#        'TV (Day time) II', 'TV (Day time) III (Light)'],
#       dtype='object', length=1338)

# %%
df2.columns
# Out:
# Index(['RespID', 'wgtpop', 'Database Total Audience',
#        'Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader',
#        'Men', 'Women', 'Parents', 'Educ: graduated college plus',
#        'Educ: attended college', 'Educ: graduated high school',
#        ...
#        'Outdoor IV', 'Outdoor V (Light)', 'TV (Prime time) I (Heavy)',
#        'TV (Prime time) II', 'TV (Prime time) III', 'TV (Prime time) IV',
#        'TV (Prime time) V (Light)', 'TV (Day time) I (Heavy)',
#        'TV (Day time) II', 'TV (Day time) III (Light)'],
#       dtype='object', length=1338)

# %% [markdown]
# The features are of categorical values

# %%
df1.head()
# Out:
#            RespID  wgtpop  Database Total Audience  \
# 25154  6700100119     288                        1
# 25158  6700101102    1130                        1
# 25165  6700101513     160                        1
# 25166  6700101554     285                        1
# 25168  6700101557     255                        1
#
#        Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader  \
# 25154                                                  1
# 25158                                                  1
# 25165                                                  1
# 25166                                                  1
# 25168                                                  1
#
#        Men  Women  Parents  Educ: graduated college plus  \
# 25154    0      1        0                             1
# 25158    0      1        0                             0
# ...

# %%
df1.tail()
# Out:
#            RespID  wgtpop  Database Total Audience  \
# 43999  7000284009     374                        1
# 44011  7000288806     816                        1
# 44012  7000288809     292                        1
# 44013  7000288814     600                        1
# 44014  7000289403     299                        1
#
#        Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader  \
# 43999                                                  1
# 44011                                                  1
# 44012                                                  1
# 44013                                                  1
# 44014                                                  1
#
#        Men  Women  Parents  Educ: graduated college plus  \
# 43999    0      1        0                             0
# 44011    0      1        0                             0
# ...

# %%
df2.head()
# Out:
#            RespID  wgtpop  Database Total Audience  \
# 25156  6700100910     335                        1
# 25157  6700100911     394                        1
# 25159  6700101109     504                        1
# 25162  6700101507     372                        1
# 25163  6700101508     918                        1
#
#        Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader  \
# 25156                                                  1
# 25157                                                  1
# 25159                                                  0
# 25162                                                  0
# 25163                                                  1
#
#        Men  Women  Parents  Educ: graduated college plus  \
# 25156    0      1        1                             1
# 25157    0      1        1                             1
# ...

# %%
df2.tail()
# Out:
#            RespID  wgtpop  Database Total Audience  \
# 44004  7000286208     177                        1
# 44005  7000286211     178                        1
# 44007  7000288411     102                        1
# 44009  7000288802     313                        1
# 44010  7000288804     131                        1
#
#        Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader  \
# 44004                                                  1
# 44005                                                  1
# 44007                                                  1
# 44009                                                  1
# 44010                                                  1
#
#        Men  Women  Parents  Educ: graduated college plus  \
# 44004    0      1        1                             1
# 44005    0      1        1                             0
# ...

# %% [markdown]
# I would like to combine both data sets

# %%
df = pd.concat([df1,df2],axis=0,join='outer')

# %%
print(df.columns)
# Out:
# Index(['RespID', 'wgtpop', 'Database Total Audience',
#        'Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader',
#        'Men', 'Women', 'Parents', 'Educ: graduated college plus',
#        'Educ: attended college', 'Educ: graduated high school',
#        ...
#        'Outdoor IV', 'Outdoor V (Light)', 'TV (Prime time) I (Heavy)',
#        'TV (Prime time) II', 'TV (Prime time) III', 'TV (Prime time) IV',
#        'TV (Prime time) V (Light)', 'TV (Day time) I (Heavy)',
#        'TV (Day time) II', 'TV (Day time) III (Light)'],
#       dtype='object', length=1338)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11189 entries, 25154 to 44010
# Columns: 1338 entries, RespID to TV (Day time) III (Light)
# dtypes: int64(1338)
# memory usage: 114.3 MB

# %%
df.head()
# Out:
#            RespID  wgtpop  Database Total Audience  \
# 25154  6700100119     288                        1
# 25158  6700101102    1130                        1
# 25165  6700101513     160                        1
# 25166  6700101554     285                        1
# 25168  6700101557     255                        1
#
#        Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader  \
# 25154                                                  1
# 25158                                                  1
# 25165                                                  1
# 25166                                                  1
# 25168                                                  1
#
#        Men  Women  Parents  Educ: graduated college plus  \
# 25154    0      1        0                             1
# 25158    0      1        0                             0
# ...

# %%
df.tail()
# Out:
#            RespID  wgtpop  Database Total Audience  \
# 44004  7000286208     177                        1
# 44005  7000286211     178                        1
# 44007  7000288411     102                        1
# 44009  7000288802     313                        1
# 44010  7000288804     131                        1
#
#        Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader  \
# 44004                                                  1
# 44005                                                  1
# 44007                                                  1
# 44009                                                  1
# 44010                                                  1
#
#        Men  Women  Parents  Educ: graduated college plus  \
# 44004    0      1        1                             1
# 44005    0      1        1                             0
# ...

# %%
df.isnull().sum()
# Out:
# RespID                                                                                                                                0
# wgtpop                                                                                                                                0
# Database Total Audience                                                                                                               0
# Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader    0
# Men                                                                                                                                   0
#                                                                                                                                      ..
# TV (Prime time) IV                                                                                                                    0
# ...

# %%
df["Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader"].value_counts()
# Out:
# 1    7668
# 0    3521
# Name: Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader, dtype: int64

# %% [markdown]
# This is the dataset for 18-49. These observations were selected since we are interested audience range of 18-49. There are 7668 women that fall in that age bracket.

# %%
df_n = df.loc[df["Adults 18-49 and Cellular/Mobile Phones/Smartphones: Have a Smartphone or Tablets & E-Readers - Brands: Own any tablet or e-reader"]==1]

# %%
col = [
"Census Region: North East",
"Census Region: South",
"Census Region: Midwest",
"Census Region: West",
"Mktg Region: New England",
"Mktg Region: Mid Atlantic",
"Mktg Region: East Central",
"Mktg Region: West Central",
"Mktg Region: Southeast",
"Mktg Region: Southwest",
"Mktg Region: Pacific",
"Mediamarkets: Top 5",
"Mediamarkets: Next 5",
"Mediamarkets: New York",
"Mediamarkets: Los Angeles",
"Mediamarkets: Chicago",
"HHI $200_000 or over",
"HHI $150_000-199_999",
"HHI $100_000-149_999",
"HHI $75_000-99_999",
"HHI $60_000-74_999",
"HHI $50_000-59_999",
"HHI $40_000-49_999",
"HHI $30_000-39_999",
"HHI $20_000-29_999",
"HHI <$20_000",
"My cell phone is an extension of my personality.: Disagree completely",
"My cell phone is an extension of my personality.: Disagree somewhat",
"My cell phone is an extension of my personality.: Agree somewhat",
"My cell phone is an extension of my personality.: Agree completely",
"Media Quintile/Tercile Codes: Magazines I (Heavy)",
"Magazines II",
"Magazines III",
"Magazines IV",
"Magazines V (Light)",
"Newspaper I (Heavy)",
"Newspaper II",
"Newspaper III",
"Newspaper IV",
"Newspaper V (Light)",
"Radio I (Heavy)",
"Radio II",
"Radio III",
"Radio IV",
"Radio V (Light)",
"TV (total) I (Heavy)",
"TV (total) II",
"TV (total) III",
"TV (total) IV",
"TV (total) V (Light)",
"Internet I (Heavy)",
"Internet II",
"Internet III",
"Internet IV",
"Internet V (Light)",
"Outdoor I (Heavy)",
"Outdoor II",
"Outdoor III",
"Outdoor IV",
"Outdoor V (Light)",
"TV (Prime time) I (Heavy)",
"TV (Prime time) II",
"TV (Prime time) III",
"TV (Prime time) IV",
"TV (Prime time) V (Light)",
"TV (Day time) I (Heavy)",
"TV (Day time) II",
"TV (Day time) III (Light)"]

# %%
df[col]
# Out:
#        Census Region: North East  Census Region: South  \
# 25154                          1                     0
# 25158                          1                     0
# 25165                          1                     0
# 25166                          1                     0
# 25168                          1                     0
# ...                          ...                   ...
# 44004                          0                     0
# 44005                          0                     0
# 44007                          0                     0
# 44009                          0                     0
# 44010                          0                     0
#
#        Census Region: Midwest  Census Region: West  Mktg Region: New England  \
# 25154                       0                    0                         1
# 25158                       0                    0                         0
# ...

# %%
for i in df[col].columns:
    num = df[col][i].value_counts()
    sns.barplot(x=num.index,y=num)
    plt.show()

# %%
for i in df_n[col].columns:
    num = df_n[col][i].value_counts()
    sns.barplot(x=num.index,y=num)
    plt.show()

# %%
df[weights]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-e00067dbcc7e> in <module>
# ----> 1 df[weights]
#
# NameError: name 'weights' is not defined
